# %%
import pandas as pan

# %%
data_ul = pan.read_csv("data_ulaval.csv")

# %%
data_ul
# Out:
#                           name sex                                expertise  \
# 0          Aaron Liu-Rosenbaum   m                                  Musique
# 1          Aaron Liu-Rosenbaum   m                                  Musique
# 2          Aaron Liu-Rosenbaum   m                                  Musique
# 3          Aaron Liu-Rosenbaum   m                                  Musique
# 4          Aaron Liu-Rosenbaum   m                                  Musique
# 5          Aaron Liu-Rosenbaum   m                                  Musique
# 6          Aaron Liu-Rosenbaum   m                                  Musique
# 7           Abdelhakim Bendada   m           Optique - photonique et lasers
# 8           Abdelhakim Bendada   m           Optique - photonique et lasers
# 9     Abdelwahed Mekki-Berrada   m                            Anthropologie
# 10    Abdelwahed Mekki-Berrada   m                            Anthropologie
# ...

# %%
data_ul.drop("expertise", 1).drop("sub_expertise", 1)
# Out:
#                           name sex                                   email  \
# 0          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 1          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 2          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 3          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 4          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 5          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 6          Aaron Liu-Rosenbaum   m       aaron.liu-rosenbaum@mus.ulaval.ca
# 7           Abdelhakim Bendada   m             hakim.bendada@gel.ulaval.ca
# 8           Abdelhakim Bendada   m             hakim.bendada@gel.ulaval.ca
# 9     Abdelwahed Mekki-Berrada   m  abdelwahed.mekki-berrada@ant.ulaval.ca
# 10    Abdelwahed Mekki-Berrada   m  abdelwahed.mekki-berrada@ant.ulaval.ca
# ...

# %%
data_ul.drop_duplicates()
data_ul.describe()
# Out:
#                     name   sex         expertise          sub_expertise  \
# count               4740  4740              4740                   4740
# unique               973     2               122                   3137
# top     Thierry Ollevier     m  Droit et justice  Philosophie politique
# freq                  22  3238               215                     17
#
#                                  email          number        university  \
# count                             4740            4299              4740
# unique                             978             818                 1
# top     thierry.ollevier@chm.ulaval.ca  (418) 656-2131  Université Laval
# freq                                22              38              4740
#
#           city
# count     4740
# unique       1
# top     Québec
# freq      4740

# %%
data_ul
# Out:
#                           name sex                                expertise  \
# 0          Aaron Liu-Rosenbaum   m                                  Musique
# 1          Aaron Liu-Rosenbaum   m                                  Musique
# 2          Aaron Liu-Rosenbaum   m                                  Musique
# 3          Aaron Liu-Rosenbaum   m                                  Musique
# 4          Aaron Liu-Rosenbaum   m                                  Musique
# 5          Aaron Liu-Rosenbaum   m                                  Musique
# 6          Aaron Liu-Rosenbaum   m                                  Musique
# 7           Abdelhakim Bendada   m           Optique - photonique et lasers
# 8           Abdelhakim Bendada   m           Optique - photonique et lasers
# 9     Abdelwahed Mekki-Berrada   m                            Anthropologie
# 10    Abdelwahed Mekki-Berrada   m                            Anthropologie
# ...

# %% [markdown]
# #
